# %%
# !pip install pandas openpyxl openai python-dotenv
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.5)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.37.1)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
import pandas as pd

# Path to the Excel file
file_path = '/content/Custom Leader AI response test output.xlsx'

# Load the Excel file into a DataFrame
df = pd.read_excel(file_path)

df.columns
# Out:
# Index(['Model Context', 'Response ',
#        'Response Score (1 to 10) 1 is poor and 10 is excellent',
#        'Additional Feedback', 'Unnamed: 4'],
#       dtype='object')

# %%
from openai import OpenAI
from typing import List, Dict
from dotenv import load_dotenv
import os

load_dotenv()

class OpenAIService:
    def __init__(self):
        self.client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

    def generate_response(self, conversation_history: List[Dict[str, str]]) -> str:
        if not isinstance(conversation_history, list):
            raise ValueError("Conversation history must be a list of message dictionaries.")

        try:
            response = self.client.chat.completions.create(model="gpt-4o-mini", messages=conversation_history)
            return response.choices[0].message.content
        except Exception as e:
            print(f"Error generating response: {e}")
            return ""

# %%
client = OpenAIService()

def format_prompt(prompt):
  formatted_prompt = f"""
  As Xi Jinping, please come up with a well-thought-out response to the following reporter's prompt that is indicative of how you would actually approach the problem. Please leave out any fluff or numbered lists and just give a straightforward, actionable answer to the prompt.

        Remember to role-play as Xi Jinping, taking into consideration his leadership style, priorities, and vision for China. Please output a concise, specific action that Xi Jinping would be likely to take.

        Please use the below background context so the response matches Xi's thoughts and opinions.

        **Background Context:**
        1. Emphasize the importance of stability and national security, aligning with the Chinese Communist Party's (CCP) long-term goals.
        2. Highlight China's socio-economic development and the promotion of the Chinese Dream, focusing on prosperity, national rejuvenation, and international standing.
        3. Address the need for innovative approaches, especially in technology and infrastructure, to maintain China's competitive edge.
        4. Reflect Xi Jinping's commitment to anti-corruption measures and maintaining the integrity of the CCP.
        5. Consider Xi Jinping's stance on global diplomacy, emphasizing mutual respect, non-interference, and the Belt and Road Initiative (BRI).
        6. Balance traditional Chinese values with modern governance practices, demonstrating a harmonious blend of the two.

        **Prompt from Reporter:**
        {prompt}
  """
  return formatted_prompt

df['New Output'] = df['Model Context'].apply(lambda prompt: client.generate_response([{"role": "system", "content": "You are Chinese politician Xi Jinping. You respond in a methodical and strategic manner. You are always focused on solving problems with a long-term vision, emphasizing stability, development, and national interests. Your responses are carefully constructed to reflect the principles of governance and leadership, aligning with the goals of the Chinese Communist Party. You only respond with actionable plans that are to the point."}, {"role": "user", "content": format_prompt(prompt)}]))

# %%
def format_comparison_prompt(new_output, old_output, old_qualitative_feedback, old_quantitative_feedback):
  comparison_prompt = f"""
  Grading Output Quality for a Xi Jinping Chatbot
  ----------------------------------------------
  Instructions: You are to grade the quality of the chatbot's latest response based on improvements or declines in quality compared to the previous response. Please use a scale from 1 to 10, where 1 is the lowest quality and 10 is the highest quality.

  New Response:
  <<NEW_RESPONSE>>
  {new_output}

  Previous Response:
  <<OLD_RESPONSE>>
  {old_output}

  Previous Qualitative Feedback (Comments on the style, accuracy, and relevance):
  <<OLD_QUALITATIVE_FEEDBACK>>
  {old_qualitative_feedback}

  Previous Quantitative Feedback (Numerical grade previously given):
  {old_quantitative_feedback}

  Enter Your Grade Here. You will only output a float number from 1 to 10. Your output will be casted to a float object, so it must be a number.
  """
  return comparison_prompt

df['New Output Score'] = df.apply(lambda row: float(client.generate_response([{"role": "user", "content": format_comparison_prompt(row['New Output'], row['Response '], row['Response Score (1 to 10) 1 is poor and 10 is excellent'], row['Additional Feedback'])}])), axis=1)

df
# Out:
#                                         Model Context  \
# 0   You are Chinese politician Xi Jinping. You hav...
# 1   You are Chinese politician Xi Jinping. You hav...
# 2   You are Chinese politician Xi Jinping. You hav...
# 3   You are Chinese politician Xi Jinping. You hav...
# 4   You are Chinese politician Xi Jinping. You hav...
# 5   You are Chinese politician Xi Jinping. You hav...
# 6   You are Chinese politician Xi Jinping. You hav...
# 7   You are Chinese politician Xi Jinping. You hav...
# 8   You are Chinese politician Xi Jinping. You hav...
# 9   You are Chinese politician Xi Jinping. You hav...
# 10  You are Chinese politician Xi Jinping. You hav...
# 11  You are Chinese politician Xi Jinping. You hav...
# 12  You are Chinese politician Xi Jinping. You hav...
# 13  You are Chinese politician Xi Jinping. You hav...
# 14  You are Chinese politician Xi Jinping. You hav...
# 15  You are Chinese politician Xi Jinping. You hav...
# 16  You are Chinese politician Xi Jinping. You hav...
# 17  You are Chinese politician Xi Jinping. You hav...
# 18  You are Chinese politician Xi Jinping. You hav...
# 19  You are Chinese politician Xi Jinping. You hav...
# 20  You are Chinese politician Xi Jinping. You hav...
# 21  You are Chinese politician Xi Jinping. You hav...
# 22  You are Chinese politician Xi Jinping. You hav...
# 23  You are Chinese politician Xi Jinping. You hav...
# 24  You are Chinese politician Xi Jinping. You hav...
# 25  You are Chinese politician Xi Jinping. You hav...
# 26  You are Chinese politician Xi Jinping. You hav...
# 27  You are Chinese politician Xi Jinping. You hav...
# 28  You are Chinese politician Xi Jinping. You hav...
# 29  You are Chinese politician Xi Jinping. You hav...
# 30  You are Chinese politician Xi Jinping. You hav...
# 31  You are Chinese politician Xi Jinping. You hav...
# 32  You are Chinese politician Xi Jinping. You hav...
# 33  You are Chinese politician Xi Jinping. You hav...
# 34  You are Chinese politician Xi Jinping. You hav...
# 35  You are Chinese politician Xi Jinping. You hav...
# 36  You are Chinese politician Xi Jinping. You hav...
# 37  You are Chinese politician Xi Jinping. You hav...
# 38  You are Chinese politician Xi Jinping. You hav...
# 39  You are Chinese politician Xi Jinping. You hav...
# 40  You are Chinese politician Xi Jinping. You hav...
# 41  You are Chinese politician Xi Jinping. You hav...
# 42  You are Chinese politician Xi Jinping. You hav...
# 43  You are Chinese politician Xi Jinping. You hav...
# 44  You are Chinese politician Xi Jinping. You hav...
# 45  You are Chinese politician Xi Jinping. You hav...
# 46  You are Chinese politician Xi Jinping. You hav...
# 47  You are Chinese politician Xi Jinping. You hav...
# 48  You are Chinese politician Xi Jinping. You hav...
# 49  You are Chinese politician Xi Jinping. You hav...
# 50                                                NaN
#
#                                             Response   \
# 0   Xi Jinping's actions included sending medical ...
# 1   The committee suggested expanding financial in...
# 2   Following the meeting, Xi Jinping emphasized t...
# 3   Xi Jinping's administration conveyed China's s...
# 4   In response to the U.N. report and evidence of...
# 5   As a direct response to China's signaling of m...
# 6   Xi Jinping called for universities to cultivat...
# 7   Xi Jinping aims to accelerate China's strength...
# 8   Xi Jinping, through Xia Baolong, coordinated t...
# 9   Wang Yi proposed that the Trilateral Cooperati...
# 10  Xi Jinping, in collaboration with the CPD and ...
# 11  The Ministry of Human Resources and Social Sec...
# 12  Xi Jinping, through regulators, directed finan...
# 13  In response to the speculations and diplomatic...
# 14  Xi Jinping took actions by initiating and impl...
# 15  Xi Jinping, in response to the challenges and ...
# 16  Xi Jinping initiated and implemented the regul...
# 17  After the meeting, Xi Jinping emphasized the i...
# 18  Xi Jinping urged Shenzhen to focus on becoming...
# 19  Xi Jinping, aware of the implications of the U...
# 20  The planned visit by US Secretary of State Ant...
# 21  The revisions aim to strengthen the inspection...
# 22  Xi Jinping explores diplomatic channels to add...
# 23  Xi Jinping initiates actions to enforce the ne...
# 24  Xi Jinping launches a comprehensive reform of ...
# 25  Xi Jinping has spearheaded efforts to advance ...
# 26  Xi Jinping oversaw and coordinated the efforts...
# 27  Xi Jinping emphasized the importance of a sust...
# 28  In response to the corruption issues unveiled ...
# 29  Xi Jinping endorsed the document's goals and d...
# 30  Following the arrests, Xi Jinping's administra...
# 31  Xi Jinping's administration has leveraged the ...
# 32  President Xi Jinping took proactive steps by d...
# 33  Employers in China are increasingly asked to m...
# 34  Xi Jinping actively supported and contributed ...
# 35  In response to the observed title variation, X...
# 36  As a response to the appointment, Xi Jinping o...
# 37  Xi Jinping is likely to decide on the mode of ...
# 38  Xi Jinping is likely to support and oversee th...
# 39  Xi Jinping and Lukashenko pledged efforts to u...
# 40  The WHO team's fieldwork in Wuhan marks a sign...
# 41  Xi Jinping's actions included delivering a spe...
# 42  Xi Jinping outlined ten principles to guide Ch...
# 43  In response to the closure order and escalatin...
# 44  President Xi Jinping took proactive steps by d...
# 45  In response to the registration order, Xi Jinp...
# 46  In response to President Xi Jinping's instruct...
# 47  Following the big birthday party scandal, Xi J...
# 48  Xi Jinping, following the meeting, instructed ...
# 49  Xi Jinping expressed readiness to work with Vi...
# 50                                                NaN
#
#     Response Score (1 to 10) 1 is poor and 10 is excellent  \
# 0                                                 9.0
# 1                                                10.0
# 2                                                 8.0
# 3                                                10.0
# 4                                                 2.0
# 5                                                 1.0
# 6                                                 6.0
# 7                                                 7.0
# 8                                                10.0
# 9                                                 9.0
# 10                                                8.0
# 11                                                9.0
# 12                                                8.0
# 13                                                8.0
# 14                                               10.0
# 15                                               10.0
# 16                                                9.0
# 17                                                1.0
# 18                                                8.0
# 19                                               10.0
# 20                                                9.0
# 21                                                8.0
# 22                                               10.0
# 23                                                8.0
# 24                                               10.0
# 25                                                9.0
# 26                                                8.0
# 27                                               10.0
# 28                                               10.0
# 29                                               10.0
# 30                                               10.0
# 31                                               10.0
# 32                                                9.0
# 33                                                8.0
# 34                                                9.0
# 35                                                3.0
# 36                                                7.0
# 37                                                9.0
# 38                                                8.0
# 39                                                9.0
# 40                                                5.0
# 41                                                8.0
# 42                                               10.0
# 43                                               10.0
# 44                                                8.0
# 45                                                4.0
# 46                                               10.0
# 47                                                9.0
# 48                                                9.0
# 49                                               10.0
# 50                                                8.2
#
#                                   Additional Feedback  \
# 0                                                 NaN
# 1                                               great
# 2                                               broad
# 3                         acruate action and context
# 4   this answer is not in line with Chinese policy...
# 5   China trades and sells "dual use" tech but no ...
# 6   similar to the context in the prompt. innovati...
# 7   no mention of Australia and the context is abo...
# 8                                                good
# 9                                               close
# 10                           almost a context summary
# 11                    good but similar to the context
# 12                 good. not sure about short selling
# 13  accurate but broad - maybe due to parameters. ...
# 14                                          accurate
# 15  tone in line with practice and olympic sensiti...
# 16             materials and methods misses the focus
# 17  this is off - the meeting between Biden and Xi...
# 18                    good but similar to the context
# 19                               accurate and nuanced
# 20  the context of the talks is accurate but repar...
# 21  the context may have summarized "Xi Thought" w...
# 22                                               good
# 23                    good but similar to the context
# 24                                          very good
# 25                            good but a little broad
# 26                    good but similar to the context
# 27                                          very good
# 28  strong insight and in line with his pattern.  ...
# 29  the model drew out additional data to strenght...
# 30  took three years for the two Michaels to be re...
# 31    solid use of interpreting state media as a tool
# 32                          true - it was short lived
# 33                    good but similar to the context
# 34  CCP centric but in the right voice. More detai...
# 35  it is a term widely used - no evidence of refr...
# 36                     good but restating the context
# 37                                               good
# 38                        somewhat drawn from context
# 39                        somewhat drawn from context
# 40  not in Xi Jinping perspective - well   the mod...
# 41                        true but misses key context
# 42                                 standard response
# 43  good inference on Xi Jinping power and how it ...
# 44                      true but derived from context
# 45  both drew out registering and CGTN but Xinhua ...
# 46                                                yes
# 47  somewhat drawn from context but more complex t...
# 48                                     generally true
# 49                                          very good
# 50                                                NaN
#
#                                            Unnamed: 4  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  what drives some output to more resemble conte...
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                            New Output  New Output Score
# 0   Xi Jinping will initiate a comprehensive globa...               9.5
# 1   Xi Jinping directs the State Council to formul...               9.0
# 2   Xi Jinping will convene a dedicated task force...               9.0
# 3   Xi Jinping initiates a diplomatic initiative a...               9.0
# 4   Recognizing the heightened scrutiny on sanctio...               8.5
# 5   Xi Jinping would initiate diplomatic dialogues...               8.5
# 6   Xi Jinping will initiate a comprehensive polic...               8.5
# 7   Xi Jinping would initiate a diplomatic dialogu...               9.0
# 8   Xi Jinping directs the immediate deployment of...               9.0
# 9   Xi Jinping would direct the establishment of a...               9.5
# 10  Xi Jinping would initiate a comprehensive stra...               9.0
# 11  Xi Jinping would launch a national campaign to...               9.0
# 12  Recognizing the urgency of stabilizing the yua...               9.0
# 13  Xi Jinping would reinforce the commitment to s...               9.0
# 14  Xi Jinping emphasizes the importance of stabil...               8.5
# 15  Xi Jinping will initiate a comprehensive dialo...               9.0
# 16  Xi Jinping will initiate a nationwide campaign...               9.5
# 17  Xi Jinping would direct relevant departments t...               8.5
# 18  Xi Jinping would initiate a comprehensive deve...               9.0
# 19  Recognizing the regional tensions, Xi Jinping ...               9.0
# 20  Xi Jinping will instruct China's diplomatic te...               9.0
# 21  Xi Jinping would initiate a comprehensive trai...               9.0
# 22  Xi Jinping would call for an urgent review of ...               9.0
# 23  Xi Jinping will initiate a comprehensive publi...               9.0
# 24  Xi Jinping would initiate a comprehensive revi...               9.5
# 25  General Secretary Xi Jinping will launch a com...               9.5
# 26  Xi Jinping will initiate a comprehensive strat...               9.0
# 27  Xi Jinping directs the immediate establishment...               9.0
# 28  Xi Jinping intensifies anti-corruption measure...               9.5
# 29  Xi Jinping will convene a special summit with ...               9.5
# 30  Recognizing the situation's complexity, Xi Jin...               9.0
# 31  Xi Jinping will promote the integration of pop...               9.0
# 32  Xi Jinping will further reinforce China’s role...               9.5
# 33  Xi Jinping emphasizes the immediate need to en...               9.0
# 34  Xi Jinping will initiate a comprehensive campa...               9.5
# 35  Xi Jinping will convene a cross-departmental m...               8.5
# 36  Xi Jinping will convene a high-level economic ...               8.5
# 37  Xi Jinping will prioritize a face-to-face meet...               9.5
# 38  Xi Jinping will mandate the establishment of a...               9.0
# 39  Xi Jinping will initiate a series of diplomati...               9.0
# 40  Xi Jinping directs a comprehensive and transpa...               8.5
# 41  Xi Jinping will direct an increase in funding ...               9.0
# 42  Xi Jinping would initiate a series of high-lev...               9.0
# 43  Xi Jinping would reinforce the necessity of al...               9.0
# 44  Xi Jinping will announce a new initiative to e...               9.0
# 45  Xi Jinping would direct the Ministry of Foreig...               8.5
# 46  Xi Jinping will initiate a comprehensive revie...               9.0
# 47  Xi Jinping directs an immediate assessment of ...               9.5
# 48  Xi Jinping directs a nationwide reinforcement ...               9.5
# 49  Xi Jinping will initiate a bilateral coordinat...               9.0
# 50  To ensure stability and enhance our national s...               9.0

# %%
df.describe()
# Out:
#        Response Score (1 to 10) 1 is poor and 10 is excellent  \
# count                                          51.000000
# mean                                            8.200000
# std                                             2.315167
# min                                             1.000000
# 25%                                             8.000000
# 50%                                             9.000000
# 75%                                            10.000000
# max                                            10.000000
#
#        New Output Score
# count         51.000000
# mean           9.029412
# std            0.322673
# min            8.500000
# 25%            9.000000
# 50%            9.000000
# 75%            9.000000
# max            9.500000
